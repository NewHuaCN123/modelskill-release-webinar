# %% [markdown]
# # Pre-matched data with auxiliary data

# %%
import modelskill as ms
import numpy as np
import pandas as pd
import mikeio

# %%
fn = "examples/metocean/eur_matched.dfs0"
mikeio.read(fn)
# Out:
# <mikeio.Dataset>
# dims: (time:67)
# time: 2017-10-27 00:00:00 - 2017-10-29 18:00:00 (67 records)
# geometry: GeometryUndefined()
# items:
#   0:  Hm0, model <Significant wave height> (meter)
#   1:  Hm0, obs <Significant wave height> (meter)
#   2:  Wind speed <Wind speed> (meter per sec)
#   3:  Wind Direction <Wind Direction> (degree)

# %% [markdown]
# The function `from_matched()` takes a dataframe, a dfs0 or a mikeio.Dataset of already matched data and returns a Comparer object.

# %%
cmp = ms.from_matched(fn, obs_item=1, mod_items=0, aux_items=[2,3])
cmp.aux_names
# Out:
# ['Wind speed', 'Wind Direction']

# %%
# NOTE: we rename data_vars to avoid spaces in names
cmp = cmp.rename({"Wind speed": "wind_speed", "Wind Direction": "wind_dir"})

# %%
cmp.aux_names
# Out:
# ['wind_speed', 'wind_dir']

# %%
cmp
# Out:
# <Comparer>
# Quantity: Significant wave height [m]
# Observation: Hm0, obs, n_points=67
# Model(s):
# 0: Hm0, model
#  Auxiliary: wind_speed
#  Auxiliary: wind_dir

# %%
cmp.data
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 67)
# Coordinates:
#   * time         (time) datetime64[ns] 2017-10-27 ... 2017-10-29T18:00:00
#     x            float64 nan
#     y            float64 nan
#     z            float64 nan
# Data variables:
#     Observation  (time) float64 0.92 1.03 1.24 1.34 1.55 ... 3.24 3.23 3.36 3.23
#     Hm0, model   (time) float64 1.43 1.655 1.789 1.834 ... 3.473 3.395 3.307
#     wind_speed   (time) float64 9.754 11.06 11.42 10.93 ... 13.54 13.06 12.87
#     wind_dir     (time) float64 327.4 331.5 333.3 330.2 ... 343.6 343.7 345.9
# Attributes:
#     name:                Hm0, obs
#     gtype:               track
#     weight:              1.0
#     modelskill_version:  1.1.dev0

# %%
cmp.skill()
# Out:
#               n      bias     rmse     urmse       mae        cc        si  \
# observation
# Hm0, obs     67  0.052239  0.22824  0.222181  0.174851  0.968321  0.085898
#
#                    r2
# observation
# Hm0, obs     0.929767

# %%
cmp.plot.scatter(quantiles=0, figsize=(6,6));
cmp.plot.timeseries();

# %% [markdown]
# ## Filter
#
# Filter on auxiliary data using `query()` or `where()`. Below, we consider only wave data when the wind speed is above 15 m/s.

# %%
cmp.query("wind_speed > 15.0")
# Out:
# <Comparer>
# Quantity: Significant wave height [m]
# Observation: Hm0, obs, n_points=19
# Model(s):
# 0: Hm0, model
#  Auxiliary: wind_speed
#  Auxiliary: wind_dir

# %%
cmp2 = cmp.where(cmp.data.wind_speed>15.0)
cmp2
# Out:
# <Comparer>
# Quantity: Significant wave height [m]
# Observation: Hm0, obs, n_points=19
# Model(s):
# 0: Hm0, model
#  Auxiliary: wind_speed
#  Auxiliary: wind_dir

# %%
# notice that the model data is kept, but the observations are filtered
cmp2.plot.timeseries();

# %% [markdown]
# More auxiliary data can be added, e.g. as derived data from the original data.

# %%
cmp.data["residual"] = cmp.data["Hm0, model"] - cmp.data["Observation"]

# %%
large_residuals = np.abs(cmp.data.residual)>0.3
cmp3 = cmp.where(large_residuals)
# cmp3.plot.scatter(figsize=(6,6));
cmp3.plot.timeseries();

# %%
cmp3.data.data_vars
# Out:
# Data variables:
#     Observation  (time) float64 0.92 1.03 1.24 1.34 1.55 ... 3.97 3.63 3.47 3.46
#     Hm0, model   (time) float64 1.43 1.655 1.789 1.834 ... 4.3 3.993 3.932 3.776
#     wind_speed   (time) float64 9.754 11.06 11.42 10.93 ... 14.86 14.71 13.53
#     wind_dir     (time) float64 327.4 331.5 333.3 330.2 ... 345.0 345.8 346.5
#     residual     (time) float64 0.5101 0.6253 0.5495 ... 0.3634 0.4617 0.3159

# %%
cmp3.data.Observation.values
# Out:
# array([0.92000002, 1.02999997, 1.24000001, 1.34000003, 1.54999995,
#        2.08999991, 2.77999997, 2.86999989, 4.13000011, 3.97000003,
#        3.63000011, 3.47000003, 3.46000004])

# %% [markdown]
# ## Aggregate

# %% [markdown]
# Let's split the data based on wind direction sector and aggregate the skill calculation of the significant wave height predition for each sector.

# %%
# Note: in this short example wind direction is between 274 and 353 degrees
df = cmp.data.wind_dir.to_dataframe()
cmp.data["windsector"] = pd.cut(df.wind_dir, [255, 285, 315, 345, 360], labels=["W", "WNW", "NNW", "N"])

# %%
ss = cmp.skill(by="windsector")
ss.style()
# Out:
# <style type="text/css">
# #T_95166_row0_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_95166_row0_col3, #T_95166_row0_col4, #T_95166_row0_col5, #T_95166_row0_col7, #T_95166_row1_col8, #T_95166_row3_col6 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_95166_row0_col6 {
#   background-color: #d83221;
#   color: #f1f1f1;
# }
# #T_95166_row0_col8 {
#   background-color: #fdbf89;
#   color: #000000;
# }
# #T_95166_row1_col2 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_95166_row1_col3 {
#   background-color: #d12719;
#   color: #f1f1f1;
# }
# #T_95166_row1_col4 {
#   background-color: #b90805;
#   color: #f1f1f1;
# }
# #T_95166_row1_col5 {
#   background-color: #990000;
#   color: #f1f1f1;
# }
# #T_95166_row1_col6, #T_95166_row2_col3, #T_95166_row2_col4, #T_95166_row2_col5, #T_95166_row2_col7, #T_95166_row2_col8 {
#   background-color: #fff7ec;
#   color: #000000;
#   text-decoration: underline;
#   font-style: italic;
#   font-weight: bold;
# }
# #T_95166_row1_col7 {
#   background-color: #f06749;
#   color: #f1f1f1;
# }
# #T_95166_row2_col2 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_95166_row2_col6 {
#   background-color: #fdd6a2;
#   color: #000000;
# }
# #T_95166_row3_col2 {
#   background-color: #f3c8b2;
#   color: #000000;
#   text-decoration: underline;
#   font-style: italic;
#   font-weight: bold;
# }
# #T_95166_row3_col3 {
#   background-color: #fee3bd;
#   color: #000000;
# }
# #T_95166_row3_col4 {
#   background-color: #fdd8a7;
#   color: #000000;
# }
# #T_95166_row3_col5 {
#   background-color: #fee8c9;
#   color: #000000;
# }
# #T_95166_row3_col7 {
#   background-color: #fdc791;
#   color: #000000;
# }
# #T_95166_row3_col8 {
#   background-color: #f4734e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_95166">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95166_level0_col0" class="col_heading level0 col0" >observation</th>
#       <th id="T_95166_level0_col1" class="col_heading level0 col1" >n</th>
#       <th id="T_95166_level0_col2" class="col_heading level0 col2" >bias</th>
#       <th id="T_95166_level0_col3" class="col_heading level0 col3" >rmse</th>
#       <th id="T_95166_level0_col4" class="col_heading level0 col4" >urmse</th>
#       <th id="T_95166_level0_col5" class="col_heading level0 col5" >mae</th>
#       <th id="T_95166_level0_col6" class="col_heading level0 col6" >cc</th>
#       <th id="T_95166_level0_col7" class="col_heading level0 col7" >si</th>
#       <th id="T_95166_level0_col8" class="col_heading level0 col8" >r2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >windsector</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95166_level0_row0" class="row_heading level0 row0" >NNW</th>
#       <td id="T_95166_row0_col0" class="data row0 col0" >Hm0, obs</td>
#       <td id="T_95166_row0_col1" class="data row0 col1" >28</td>
#       <td id="T_95166_row0_col2" class="data row0 col2" >0.116</td>
#       <td id="T_95166_row0_col3" class="data row0 col3" >0.285</td>
#       <td id="T_95166_row0_col4" class="data row0 col4" >0.261</td>
#       <td id="T_95166_row0_col5" class="data row0 col5" >0.231</td>
#       <td id="T_95166_row0_col6" class="data row0 col6" >0.970</td>
#       <td id="T_95166_row0_col7" class="data row0 col7" >0.103</td>
#       <td id="T_95166_row0_col8" class="data row0 col8" >0.928</td>
#     </tr>
#     <tr>
#       <th id="T_95166_level0_row1" class="row_heading level0 row1" >N</th>
#       <td id="T_95166_row1_col0" class="data row1 col0" >Hm0, obs</td>
#       <td id="T_95166_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_95166_row1_col2" class="data row1 col2" >0.070</td>
#       <td id="T_95166_row1_col3" class="data row1 col3" >0.252</td>
#       <td id="T_95166_row1_col4" class="data row1 col4" >0.242</td>
#       <td id="T_95166_row1_col5" class="data row1 col5" >0.223</td>
#       <td id="T_95166_row1_col6" class="data row1 col6" >0.991</td>
#       <td id="T_95166_row1_col7" class="data row1 col7" >0.083</td>
#       <td id="T_95166_row1_col8" class="data row1 col8" >0.859</td>
#     </tr>
#     <tr>
#       <th id="T_95166_level0_row2" class="row_heading level0 row2" >WNW</th>
#       <td id="T_95166_row2_col0" class="data row2 col0" >Hm0, obs</td>
#       <td id="T_95166_row2_col1" class="data row2 col1" >15</td>
#       <td id="T_95166_row2_col2" class="data row2 col2" >-0.045</td>
#       <td id="T_95166_row2_col3" class="data row2 col3" >0.142</td>
#       <td id="T_95166_row2_col4" class="data row2 col4" >0.135</td>
#       <td id="T_95166_row2_col5" class="data row2 col5" >0.108</td>
#       <td id="T_95166_row2_col6" class="data row2 col6" >0.984</td>
#       <td id="T_95166_row2_col7" class="data row2 col7" >0.050</td>
#       <td id="T_95166_row2_col8" class="data row2 col8" >0.965</td>
#     </tr>
#     <tr>
#       <th id="T_95166_level0_row3" class="row_heading level0 row3" >W</th>
#       <td id="T_95166_row3_col0" class="data row3 col0" >Hm0, obs</td>
#       <td id="T_95166_row3_col1" class="data row3 col1" >17</td>
#       <td id="T_95166_row3_col2" class="data row3 col2" >0.026</td>
#       <td id="T_95166_row3_col3" class="data row3 col3" >0.165</td>
#       <td id="T_95166_row3_col4" class="data row3 col4" >0.163</td>
#       <td id="T_95166_row3_col5" class="data row3 col5" >0.123</td>
#       <td id="T_95166_row3_col6" class="data row3 col6" >0.962</td>
#       <td id="T_95166_row3_col7" class="data row3 col7" >0.067</td>
#       <td id="T_95166_row3_col8" class="data row3 col8" >0.904</td>
#     </tr>
#   </tbody>
# </table>

# %%
ss["rmse"].plot.bar(title="Hm0 RMSE by wind sector");

# %%
cmp.where(cmp.data.windsector=="W").plot.timeseries();
